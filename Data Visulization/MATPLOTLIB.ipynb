# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[5,6,7,8]

plt.plot(x,y)  #lineplot
plt.show()

# %%
oskar_moviess=[
    "the dark night",
    "the hurt loker",
    "the kings speech",
    "the artiest",
    "argo"
]
years=[2008,2009,2010,2011,2012]
oskar_revanue=[1005,170,427,133,232]  #in M$

plt.plot(years,oskar_revanue)

# METHODS OF THE DATA VISUALIZATION

# 1.heading on the top
plt.title("Osker Movies Revanue in Each Year")

# make the exis heading
plt.xlabel("YEARS")
plt.ylabel("REVANUE (IN $M)")

# %%
# NON OSLER REVANUES DATA

non_osker_movies=["slundog","avatar","inception","hugo","lincoln"]
# non_osker_years=[2008,2009,2010,2011,2012]
non_oskar_revanue=[234,353,543,443,544 ] 

# provide lables on the data
plt.plot(years,oskar_revanue,label="osker movies")
plt.plot(years,non_oskar_revanue,label="Non_osker_movies")

# provide title ,x and y exis type
plt.title("Osker Movies Revanue vs Non osker revanue in Each Year")
plt.xlabel("YEARS")
plt.ylabel("REVANUE (IN $M)")

plt.legend() #compare lebel and define its color 


plt.style.available
plt.style.use("dark_background")
plt.style.use("_classic_test_patch")
plt.style.use("_mpl-gallery")
plt.style.use("ggplot")

plt.style.use("default")
plt.grid()
plt.show()

# %%
plt.style.available

# %% [markdown]
# # Formate of the chart
# # "o--b",  It is a example marker line and color that define ho we show the line
#
# # o = point of the value
# # --  = pattern of the line
# # b = color of the line
# """
# Marker
# Symbol
#
# Description
# "."
# •
#
# point
# "o"
# ⬤
#
# circle
# "v"
# ▼
#
# triangle_down
# "^"
# ▲
#
# triangle_up
# "s"
# ■
#
# square
# "p"
# ⬟
#
# pentagon
# "*"
# ★
#
# star
# "8"
# ⬢
#
# octagon """
#
# import matplotlib.pyplot as plt
#
# x = [1, 2, 3, 4, 5]
# y = [2, 4, 6, 8, 10]
#
# plt.plot(x, y, marker='o', linestyle='-', label='Data Points')
# plt.title('Simple Plot with Markers')
# plt.xlabel('X-axis')
# plt.ylabel('Y-axis')
# plt.legend()
# plt.show()

# %%
# NON OSLER REVANUES DATA

non_osker_movies=["slundog","avatar","inception","hugo","lincoln"]
# non_osker_years=[2008,2009,2010,2011,2012]
non_oskar_revanue=[234,353,543,443,544 ] 

# provide lables on the data
# plt.plot(years,oskar_revanue,"o--b",label="osker movies")
# plt.plot(years,oskar_revanue,marker='o', linestyle='--',color="r",label="osker movies")
plt.plot(years,oskar_revanue,marker='o', linestyle='--',color="g",linewidth=3,label="osker movies")
plt.plot(years,non_oskar_revanue,marker="v",label="Non_osker_movies")

# provide title ,x and y exis type
plt.title("Osker Movies Revanue vs Non osker revanue in Each Year")
plt.xlabel("YEARS")
plt.ylabel("REVANUE (IN $M)")

plt.legend() #compare lebel and define its color

# %%
movies=["the dark night","the hurt loker","the kings speech","the artiest","argo"]

years=[2008,2009,2010,2011,2012]
revanue=[1005,170,427,133,232]  #in M$

# plt.plot(movies,revanue)
plt.scatter(movies,revanue)

plt.title("Osker Movies Revanue in Each Year")
plt.xlabel("movies")
plt.ylabel("REVANUE (IN $M)")

# for maintain proper spacing and solve the overlaping problem
plt.tight_layout()

plt.savefig("final_plot.png")

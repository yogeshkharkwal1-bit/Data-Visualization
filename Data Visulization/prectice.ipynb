# %% [markdown]
# # PRECTICE QUESTION

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
days=["mon","tues","wed","thu","frid"]

cities=["new york","london","delhi","tokyo"]

tempreture=[
    [22,23,21,23,25],
    [18,19,17,20,21],
    [30,32,31,34,35],
    [25,26,24,27,28],
]

fig,axes=plt.subplots(2,2)

# city_no=0
# for i in range(2):
#     for j in range (2):
#         axes[i][j].plot(days,tempreture[city_no],marker="o")
#         axes[i][j].set_xlabel("x axis values")
#         axes[i][j].set_ylabel("y- axis values")
#         axes[i][j].set_title(cities[city_no])
#         axes[i][j].grid()
#         city_no+=1

axes=axes.flatten()

for i,ax in enumerate(axes):
    ax.plot(days,tempreture[i],marker='o')
    ax.set_title(cities[i])
    ax.grid(True)
    
fig.suptitle("weekly tempreture data according to diffrence cities")

fig.tight_layout()
fig.supxlabel("Days")
fig.supylabel("Tempreture")
# Out:
# Text(0.02, 0.5, 'Tempreture')
